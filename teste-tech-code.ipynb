# %%
# %pip install gspread oauth2client

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# %%
# 1. Definir o escopo do acesso
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']

# 2. Autenticar (Troque pelo caminho do arquivo JSON no Databricks)
creds = ServiceAccountCredentials.from_json_keyfile_name('/Volumes/workspace/default/sanduba-db/controle-sanduiches-76182f74d656 (1).json', scope)
client = gspread.authorize(creds)

# 3. Abrir a planilha pelo título
# (Certifique-se que o e-mail da service account foi adicionado como editor nela)
sheet = client.open("databricks-sheets-reader@controle-sanduiches.iam.gserviceaccount.com").sheet1

# 4. Extrair os dados para um DataFrame do Pandas
data = sheet.get_all_records()
df_sanduiches = pd.DataFrame(data)

# 5. Converter para Spark DataFrame (opcional, se quiser usar Spark)
spark_df = spark.createDataFrame(df_sanduiches)

# Ver os dados
display(spark_df)
